# %%
import pandas as pd

# %%
df1=pd.read_csv('BPM2.csv')
df1.head()
# Out:
#    Unnamed: 0       r1       r2       r3       r4       r5       r6       r7  \
# 0     1122016  3082912  1687616  1905680  2842336  2411024  1419488  2188592
# 1     1123696  1725696  3948896  2814336  2366896  1900752  1869728  2418528
# 2     1124144  2164512  1729168  2524816  2798768  1865584  2580704  2110528
# 3     1126608  4187904  3083136  1548960  2803360  1135568  1666896  1940512
# 4     1128400  3066224  1729280  3772272  1693104  2852192  1725472  2158688
#
#         r8       r9      r10
# 0  1682128  2951088  1694000
# 1  2291632  2424128  2943024
# 2  1700272  2224320  1557584
# 3  1534624  3125808  2876272
# 4  4073888  1694112  2930256

# %%
df1.set_index(df1.columns[0],inplace=True)

# %%
df1.loc[33143936]
# Out:
# r1     2240336
# r2     1413888
# r3     2906848
# r4     2002672
# r5     2210208
# r6     2041648
# r7     2772000
# r8     2845248
# r9     1969184
# r10    4067728
# Name: 33143936, dtype: int64

# %%
persuade=pd.read_csv('persuade.csv')
persuade.head()
# Out:
#    Unnamed: 0  level_0  index  Sub_flag  subscription  customer_id  \
# 0           0       13   2284        25             0      1129296
# 1           1       16   4611        25             0      1134000
# 2           2       27   1137        25             0      1142176
# 3           3       29   1186        25             0      1143520
# 4           4       30   2487        25             0      1144080
#
#    Recency_flag  Refreq  points
# 0             5       5       6
# 1             2       4      12
# 2             5       5      17
# 3             5       4       7
# 4             5       5      15

# %%
persuade.set_index(persuade.columns[0],inplace=True)

# %%
persuade.head()
# Out:
#             level_0  index  Sub_flag  subscription  customer_id  Recency_flag  \
# Unnamed: 0
# 0                13   2284        25             0      1129296             5
# 1                16   4611        25             0      1134000             2
# 2                27   1137        25             0      1142176             5
# 3                29   1186        25             0      1143520             5
# 4                30   2487        25             0      1144080             5
#
#             Refreq  points
# Unnamed: 0
# 0                5       6
# 1                4      12
# 2                5      17
# 3                4       7
# 4                5      15

# %%
persuade=persuade[['customer_id','points']]

# %%
persuade.head()
# Out:
#             customer_id  points
# Unnamed: 0
# 0               1129296       6
# 1               1134000      12
# 2               1142176      17
# 3               1143520       7
# 4               1144080      15

# %%
persuade.sort_values(by='points',ascending=False,inplace=True)

# %%
persuade.set_index(persuade.columns[0],inplace=True)

# %%
persuade.reset_index()
# Out:
#        customer_id  points
# 0         25769408      30
# 1         17797360      30
# 2         29034208      30
# 3         20085296      30
# 4         25938416      30
# 5         23881200      30
# 6         26702592      30
# 7         17126368      30
# 8         27101200      30
# 9         21605248      30
# 10        16794176      30
# 11        27135248      30
# 12         2574208      30
# 13        26993904      30
# 14        18054400      30
# 15        12550720      30
# 16         7101136      30
# 17        12196352      30
# 18         8446704      30
# 19        14944944      30
# 20        15999200      30
# 21        11996656      30
# 22         1621424      30
# 23        30432080      30
# 24         7574112      30
# 25        33320336      30
# 26        21929488      30
# 27        12931520      30
# 28        26852560      30
# 29        24647728      30
# ...            ...     ...
# 29970     30868656       1
# 29971     18129888       1
# ...

# %%
persuade.columns
# Out:
# Index(['points'], dtype='object')

# %%
persuade=pd.read_csv('persuade.csv')

persuade=persuade[['customer_id','points']]
persuade.head()
# Out:
#    customer_id  points
# 0      1129296       6
# 1      1134000      12
# 2      1142176      17
# 3      1143520       7
# 4      1144080      15

# %%
persuade.columns
# Out:
# Index(['customer_id', 'points'], dtype='object')

# %%
persuade.sort_values(by='points',ascending=False,inplace=True)

# %%
pers_list=persuade['customer_id'].reset_index()

# %%
pers_list=pers_list['customer_id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-8fc4446e8e7a> in <module>
# ----> 1 pers_list=pers_list['customer_id']
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
pers_list.to_csv('persuade2.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
i=1122016
df1.loc[i]
# Out:
# r1     3082912
# r2     1687616
# r3     1905680
# r4     2842336
# r5     2411024
# r6     1419488
# r7     2188592
# r8     1682128
# r9     2951088
# r10    1694000
# Name: 1122016, dtype: int64

# %%
dict={'id':i,'recom':df1.loc[i]}
dict
# Out:
# {'id': 1122016, 'recom': r1     3082912
#  r2     1687616
#  r3     1905680
#  r4     2842336
#  r5     2411024
#  r6     1419488
#  r7     2188592
#  r8     1682128
#  r9     2951088
#  r10    1694000
#  Name: 1122016, dtype: int64}

# %%
j=df1.loc[i]

# %%
x=df1.loc[i].to_json()

# %%
x
# Out:
# '{"r1":3082912,"r2":1687616,"r3":1905680,"r4":2842336,"r5":2411024,"r6":1419488,"r7":2188592,"r8":1682128,"r9":2951088,"r10":1694000}'

# %%
pers_list[:10].to_json('p1.json')
